# %%
import numpy as np
import pandas as pd
import pandas.io.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tushare as ts

# %%
ss = ts.get_k_data('002268', ktype='W', autype='qfq', start='2017-01-01')
dd = ts.get_k_data('002269', ktype='W', autype='qfq', start='2017-01-01')

dd = dd.set_index('date')
ss = ss.set_index('date')

# %%
frame1 = pd.DataFrame( {'id':['ball','pencil','pen','mug','ashtray'],
... 'price': [12.33,11.44,33.21,13.23,33.62]})

# %%
 frame2 = pd.DataFrame( {'id':['pencil','pencil','ball','pen'],
... 'color': ['white','red','red','black']})

# %%
frame1
# Out:
#         id  price
# 0     ball  12.33
# 1   pencil  11.44
# 2      pen  33.21
# 3      mug  13.23
# 4  ashtray  33.62
#
# [5 rows x 2 columns]

# %%
frame2
# Out:
#    color      id
# 0  white  pencil
# 1    red  pencil
# 2    red    ball
# 3  black     pen
#
# [4 rows x 2 columns]

# %%
pd.merge(frame1,frame2)
# Out:
#        id  price  color
# 0    ball  12.33    red
# 1  pencil  11.44  white
# 2  pencil  11.44    red
# 3     pen  33.21  black
#
# [4 rows x 3 columns]

# %%
pd.merge(ss,dd, on='date')
# Out:
#     close_x  code_x        date  high_x   low_x  open_x  volume_x  close_y  \
# 0    20.520  002268  2017-01-06  20.769  19.590  19.647    178859     5.33
# 1    19.385  002268  2017-01-13  20.838  19.304  20.489    196941     4.87
# 2    19.042  002268  2017-01-20  19.435  17.645  19.272    131059     4.96
# 3    19.092  002268  2017-01-26  19.329  18.786  19.210     48854     4.85
# 4    19.110  002268  2017-02-03  19.254  18.967  19.210      7788     4.86
# 5    19.304  002268  2017-02-10  19.647  19.023  19.135    133074     5.04
# 6    19.441  002268  2017-02-17  19.634  18.886  19.385    180376     4.94
# 7    19.503  002268  2017-02-24  19.759  19.198  19.410    149384     5.17
# 8    19.696  002268  2017-03-03  19.709  19.148  19.491    161786     4.95
# 9    19.927  002268  2017-03-10  20.345  19.578  19.709    181427     4.87
# 10   20.888  002268  2017-03-17  21.642  19.740  19.946    310629     4.76
# ...

# %%
ss
# Out:
#      close    code        date    high     low    open  volume
# 0   20.520  002268  2017-01-06  20.769  19.590  19.647  178859
# 1   19.385  002268  2017-01-13  20.838  19.304  20.489  196941
# 2   19.042  002268  2017-01-20  19.435  17.645  19.272  131059
# 3   19.092  002268  2017-01-26  19.329  18.786  19.210   48854
# 4   19.110  002268  2017-02-03  19.254  18.967  19.210    7788
# 5   19.304  002268  2017-02-10  19.647  19.023  19.135  133074
# 6   19.441  002268  2017-02-17  19.634  18.886  19.385  180376
# 7   19.503  002268  2017-02-24  19.759  19.198  19.410  149384
# 8   19.696  002268  2017-03-03  19.709  19.148  19.491  161786
# 9   19.927  002268  2017-03-10  20.345  19.578  19.709  181427
# 10  20.888  002268  2017-03-17  21.642  19.740  19.946  310629
# 11  21.349  002268  2017-03-24  21.942  20.894  20.894  401563
# 12  20.171  002268  2017-03-31  21.430  19.958  21.337  226426
# 13  20.751  002268  2017-04-07  20.888  20.040  20.040  114092
# ...

# %%
ss[['close','open']].plot(grid=True, figsize=(20, 10))

# %%
ss = ss.set_index('date')

# %%
ss['close'].plot()

# %%
r= ss['close']/ss['close'][0]
r.plot()

# %%
dd = dd.set_index('date')
rd= dd['close']/dd['close'][0]
rd.plot()

# %%
code_s = '002268'
code_d = '002269'
ss = ts.get_k_data(code_s, ktype='d', autype='qfq', start='2017-01-01',end='2017-06-01')
dd = ts.get_k_data( code_d, ktype='d', autype='qfq', start='2017-01-01',end='2017-06-01')

dd = dd.set_index('date')
ss = ss.set_index('date')
pr = pd.DataFrame()

# %%
pr[code_s+'r'] = ss['close']/ss['close'][0]
pr[code_d+'r'] =dd['close']/dd['close'][0]

# %%
pr.plot()

# %%
code_s = '399300'
code_d = '000819'
ss = ts.get_k_data(code_s, index=True, start='2017-01-01',end='2017-08-05')
dd = ts.get_k_data( code_d, index=True, start='2017-01-01',end='2017-08-05')

dd = dd.set_index('date')
ss = ss.set_index('date')
pr = pd.DataFrame()
pr[code_s+'r'] = ss['close']/ss['close'][0]
pr[code_d+'r'] =dd['close']/dd['close'][0]
pr.plot()

# %%
codes=['399300','399006','000934']
names=['深圳指数','创业指数','中证券金融']

datas={};
pr = pd.DataFrame()

for x in codes:
    datas[x] =  ts.get_k_data(x, index=True, start='2014-08-01',end='2015-06-05').set_index('date')
    pr[x] = datas[x]['close']/datas[x]['close'][0]
pr.plot(subplots=True, style='b',
figsize=(16, 9))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x1173CDB0>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x11F7CAF0>], dtype=object)

# %%
pr.plot(figsize=(16, 9))
