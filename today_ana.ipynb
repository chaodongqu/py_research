# %%
import tushare as ts
import numpy as np
import pandas as pd 
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = ts.get_today_all()
# Out:
# [Getting data:]############################################################

# %% [markdown]
# ##### df

# %%
plt.figure(figsize=(7, 4))
plt.hist(df['changepercent'],normed=True, bins=50)
plt.grid(True)

# %%
ts.get_concept_classified()
# Out:
#         code   name c_name
# 0     600007   中国国贸   外资背景
# 1     600114   东睦股份   外资背景
# 2     600132   重庆啤酒   外资背景
# 3     600182    S佳通   外资背景
# 4     600595   中孚实业   外资背景
# 5     600641   万业企业   外资背景
# 6     600779    水井坊   外资背景
# 7     600801   华新水泥   外资背景
# 8     600819   耀皮玻璃   外资背景
# 9     000001   平安银行   外资背景
# 10    000005   世纪星源   外资背景
# 11    000541   佛山照明   外资背景
# 12    000608   阳光股份   外资背景
# 13    000659  *ST中富   外资背景
# 14    000869   张 裕Ａ   外资背景
# 15    000895   双汇发展   外资背景
# 16    000932  *ST华菱   外资背景
# 17    000935   四川双马   外资背景
# 18    002032  苏 泊 尔   外资背景
# 19    002047   宝鹰股份   外资背景
# 20    600023   浙能电力   核电核能
# 21    600089   特变电工   核电核能
# 22    600202    哈空调   核电核能
# 23    600226   瀚叶股份   核电核能
# 24    600269   赣粤高速   核电核能
# 25    600292   远达环保   核电核能
# 26    600307   酒钢宏兴   核电核能
# 27    600328   兰太实业   核电核能
# 28    600416   湘电股份   核电核能
# 29    600483   福能股份   核电核能
# ...      ...    ...    ...
# 9412  600069   银鸽投资   摘帽概念
# 9413  600163   中闽能源   摘帽概念
# 9414  600179   安通控股   摘帽概念
# 9415  600242   中昌数据   摘帽概念
# 9416  600311   荣华实业   摘帽概念
# 9417  600346   恒力股份   摘帽概念
# 9418  600381   青海春天   摘帽概念
# 9419  600401  *ST海润   摘帽概念
# 9420  600408   安泰集团   摘帽概念
# 9421  600444   国机通用   摘帽概念
# 9422  600608  *ST沪科   摘帽概念
# 9423  600691   阳煤化工   摘帽概念
# 9424  600779    水井坊   摘帽概念
# 9425  600793   宜宾纸业   摘帽概念
# 9426  600870   厦华电子   摘帽概念
# 9427  600962   国投中鲁   摘帽概念
# 9428  600984   建设机械   摘帽概念
# 9429  000059   华锦股份   摘帽概念
# 9430  000068   华控赛格   摘帽概念
# 9431  000510   金路集团   摘帽概念
# 9432  000557   西部创业   摘帽概念
# 9433  000590   启迪古汉   摘帽概念
# 9434  000659  *ST中富   摘帽概念
# 9435  000677   恒天海龙   摘帽概念
# 9436  000799    酒鬼酒   摘帽概念
# 9437  000815    美利云   摘帽概念
# 9438  000927   一汽夏利   摘帽概念
# 9439  002306  *ST云网   摘帽概念
# 9440  002417    三元达   摘帽概念
# 9441  002633   申科股份   摘帽概念
#
# [9442 rows x 3 columns]
