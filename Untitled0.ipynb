# %%
import numpy as np
import pandas as pd
import pandas.io.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tushare as ts

# %%
ss = ts.get_k_data('002268', ktype='W', autype='qfq', start='2017-01-01')
ss= ss.sort(ascending=False)
ss[['close','open']].plot(grid=True, figsize=(20, 10))

# %%
ss[['close','open']].
# Out:
#   File "<ipython-input-2-1b6068a022c8>", line 1
#     ss[['close','open']].
#                              ^
# SyntaxError: invalid syntax

# %%
ss['return']=np.log(ss['close']/ss['close'].shift(1))

# %%
ss[['close','return']].plot(subplots=True, style='b',
figsize=(8, 5))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x0AB447D0>,
#        <matplotlib.axes.AxesSubplot object at 0x0ACE60D0>], dtype=object)

# %%
np.log(0.984152073)
# Out:
# -0.01597484813913768

# %%
sh = ts.get_k_data('601398', ktype='D', autype='qfq', 
                   start='2014-01-01' ,end='2015-01-01')
sh= sh.sort(ascending=True)

# %%
cy = ts.get_k_data('300024', ktype='D', autype='qfq', 
                   start='2014-01-01' ,end='2015-01-01')
cy= cy.sort(ascending=True)

# %%
sh[['close','open']].plot(grid=True, figsize=(20, 10))
cy[['close','open']].plot(grid=True, figsize=(20, 10))

# %%
cy[['close']].plot()

# %%
sh[['close']].plot()
cy[['close']].plot()
