# %%
from sqlalchemy import create_engine
import tushare as ts

# %%
df = ts.get_hist_data('000875')
engine = create_engine('mysql://root:qucd123123@127.0.0.1/test?charset=utf8')

#存入数据库

# %%
df
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2018-08-03   2.93   2.98   2.94   2.92   100909.00         -0.01     -0.34
# 2018-08-02   3.02   3.04   2.95   2.87   211329.23         -0.07     -2.32
# 2018-08-01   3.12   3.12   3.02   3.02   207487.55         -0.11     -3.51
# 2018-07-31   3.06   3.15   3.13   3.05   231877.88          0.07      2.29
# 2018-07-30   3.05   3.10   3.06   3.03   172056.94          0.01      0.33
# 2018-07-27   3.04   3.14   3.05   3.04   244817.00         -0.01     -0.33
# 2018-07-26   2.99   3.10   3.06   2.98   309234.75          0.06      2.00
# 2018-07-25   3.02   3.03   3.00   2.99   131185.94         -0.03     -0.99
# 2018-07-24   2.97   3.04   3.03   2.97   180772.91          0.05      1.68
# 2018-07-23   2.96   2.98   2.98   2.94   112716.56          0.01      0.34
# 2018-07-20   2.90   2.98   2.97   2.90   131420.91          0.05      1.71
# ...

# %%
df.to_sql('tick_data',engine   ,if_exists='append')

# %%
s2 = ts.get_growth_data(2018,1)
# Out:
# [Getting data:]###########################################################

# %%
s2 = s2.assign(year=2018 ,season=1 )

# %%
s2.head()
# Out:
#      code  name       mbrg        nprg      nav     targ       epsg      seg  \
# 0  603399  吉翔股份    77.9235  82016.2612  17.4709  24.0790  2500.0000  15.5965
# 1  600083  博信股份  3111.4297  51381.4112   1.4368  68.8194 -1395.0000  28.7323
# 2  002305  南国置业   -21.5072  35252.0618   0.5987   7.2037    93.1034  -0.5445
# 3  600256  广汇能源   196.0477  18651.0888  13.6413   5.4311  1650.0000   8.3149
# 4  600784  鲁银投资    -7.7323  10246.3998 -12.0373 -15.8046  6900.0000  -6.0635
#
#    year  season
# 0  2018       1
# 1  2018       1
# 2  2018       1
# 3  2018       1
# 4  2018       1

# %%
s2.to_sql('growth_data',engine   ,if_exists='append')

# %%
s2 = ts.get_growth_data(2018,2)
# Out:
# [Getting data:]########

# %%
s2.head()
# Out:
#      code   name       mbrg       nprg       nav       targ       epsg  \
# 0  300308   中际旭创  3902.9088  7884.9375  679.6306  1203.5490  3250.0000
# 1  600569   安阳钢铁    36.8022  3808.5876   39.9018     4.2917  3441.6667
# 2  000537   广宇发展   589.8318  3528.4675  236.5053   257.2666  1700.0000
# 3  000922  *ST佳电    38.4011  2640.1473   18.4783     5.1293  3000.0000
# 4  000877   天山股份    14.4082  2375.9114   22.2143    -7.2355   912.7586
#
#         seg
# 0  679.6306
# 1   53.5337
# 2  383.3205
# 3   18.4783
# 4   24.4935

# %%
s2 = s2.assign(year=2018 ,season=2)

# %%
s2.to_sql('growth_data',engine   ,if_exists='append')

# %%
y=2017
s=1
s2 = ts.get_growth_data(y,s)
s2 = s2.assign(year=y ,season=s)
s2.to_sql('growth_data',engine   ,if_exists='append')
# Out:
# [Getting data:]#######################################################

# %%
y=2017
s=2
s2 = ts.get_growth_data(y,s)
s2 = s2.assign(year=y ,season=s)
s2.to_sql('growth_data',engine   ,if_exists='append')
# Out:
# [Getting data:]#########################################################

# %%
y=2017
s=3
s2 = ts.get_growth_data(y,s)
s2 = s2.assign(year=y ,season=s)
s2.to_sql('growth_data',engine   ,if_exists='append')
# Out:
# [Getting data:]##########################################################

# %%
y=2017
s=4
s2 = ts.get_growth_data(y,s)
s2 = s2.assign(year=y ,season=s)
s2.to_sql('growth_data',engine   ,if_exists='append')
# Out:
# [Getting data:]###########################################################

# %%
for i in range(1,5):
    print(i)
    y=2016
    s=i
    s2 = ts.get_growth_data(y,s)
    s2 = s2.assign(year=y ,season=s)
    s2.to_sql('growth_data',engine   ,if_exists='append')
    
    print('\n')
# Out:
# 1
# [Getting data:]#################################################
#
# 2
# [Getting data:]###################################################
#
# 3
# [Getting data:]####################################################
#
# 4
# [Getting data:]###########################################################

# %%
for i in range(1,5):
    print(i)
    y=2017
    s=i
    s2 = ts.get_growth_data(y,s)
    s2 = s2.assign(year=y ,season=s)
    s2.to_sql('growth_data',engine   ,if_exists='append')
    
    print('\n')
# Out:
# 1
# [Getting data:]#######################################################
#
# 2
# [Getting data:]#########################################################
#
# 3
# [Getting data:]##########################################################
#
# 4
# [Getting data:]###########################################################

# %%
for i in range(1,5):
    print(i)
    y=2015
    s=i
    s2 = ts.get_growth_data(y,s)
    s2 = s2.assign(year=y ,season=s)
    s2.to_sql('growth_data',engine   ,if_exists='append')
    
    print('\n')
# Out:
# 1
# [Getting data:]##############################################
#
# 2
# [Getting data:]###############################################
#
# 3
# [Getting data:]###############################################
#
# 4
# [Getting data:]###########################################################
