# %%
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tushare as ts

# %%
ss = ts.get_k_data('002268', ktype='W', autype='qfq', start='2017-01-01')

# %%
# 按照日期排序
y = ss.set_index('date')

# %%
y['close'].plot()

# %%
y = ss.set_index('date')
plt.figure(figsize=(9, 6))
plt.plot(y['close'] ,'b')
plt.plot(y['close'],'ro')
plt.grid(True)

# %%
d = pd.to_datetime(y.index)
plt.plot(d,y['close'])

# %%
plt.figure(figsize=(7, 4))
plt.hist(y['close'],normed=True, bins=50)
plt.grid(True)
plt.legend(loc=0)
plt.title('Histogram')

# %%
y['volume'].plot(kind='bar')

# %%
from matplotlib.finance import quotes_historical_yahoo

# %%
years = y.index.values[1:]
counts = y['close'].values[1:]
print years
print counts
# Out:
# [u'2017-01-13' u'2017-01-20' u'2017-01-26' u'2017-02-03' u'2017-02-10'
#  u'2017-02-17' u'2017-02-24' u'2017-03-03' u'2017-03-10' u'2017-03-17'
#  u'2017-03-24' u'2017-03-31' u'2017-04-07' u'2017-04-14' u'2017-04-21'
#  u'2017-04-28' u'2017-05-05' u'2017-05-12' u'2017-05-19' u'2017-05-26'
#  u'2017-06-02' u'2017-06-09' u'2017-06-16' u'2017-06-23' u'2017-06-30'
#  u'2017-07-07' u'2017-07-14' u'2017-07-21' u'2017-07-28' u'2017-08-04'
#  u'2017-08-11' u'2017-08-18' u'2017-08-25' u'2017-09-01' u'2017-09-08'
#  u'2017-09-15' u'2017-09-22' u'2017-09-29' u'2017-10-13' u'2017-10-20'
#  u'2017-10-27' u'2017-11-03']
# [ 19.385  19.042  19.092  19.11   19.304  19.441  19.503  19.696  19.927
#   20.888  21.349  20.171  20.751  20.545  19.366  19.584  19.229  19.222
#   19.216  17.669  17.326  17.3    17.1    16.99   16.82   17.24   16.06
#   13.73   13.96   14.03   13.45   14.59   15.22   18.79   20.01   23.8
#   22.3    22.6    21.1    21.19   21.     23.86 ]

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
# unit area ellipse
rx, ry = 3., 1.
area = rx * ry * np.pi
theta = np.arange(0, 2 * np.pi + 0.01, 0.1)
verts = list(zip(rx / area * np.cos(theta), ry / area * np.sin(theta)))

x, y, s, c = np.random.rand(4, 30)
s *= 10**2.

fig, ax = plt.subplots()
ax.scatter(x, y,  marker=None, verts=verts)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import (YEARLY, DateFormatter,
                              rrulewrapper, RRuleLocator, drange)
import numpy as np
import datetime

# Fixing random state for reproducibility
np.random.seed(19680801)


# tick every 5th easter
rule = rrulewrapper(YEARLY, byeaster=1, interval=5)
loc = RRuleLocator(rule)
formatter = DateFormatter('%m/%d/%y')
date1 = datetime.date(1952, 1, 1)
date2 = datetime.date(2004, 4, 12)
delta = datetime.timedelta(days=100)

dates = drange(date1, date2, delta)
s = np.random.rand(len(dates))  # make up some random y values


fig, ax = plt.subplots()
plt.plot_date(dates, s)
ax.xaxis.set_major_locator(loc)
ax.xaxis.set_major_formatter(formatter)

# %%
sd = ts.get_k_data('002268', ktype='d', autype='qfq', start='2017-01-01')

# %%
s1 = sd.set_index('date')

# %%
 s1['close'].plot()

# %%
  s1['close'].values.std()
# Out:
# 2.6740020183817896

# %%
sd = ts.get_k_data('000973', ktype='d', autype='qfq', start='2017-10-01')
s1 = sd.set_index('date')

c_val = s1['close']

c_std = c_val.std()

print len(c_val) , c_std
# Out:
# 20 0.346134671084

# %%
 for i in range(2,len(c_val) -1 ):
        if (c_val[i-1] - c_val[i] ) > c_std :
            print '---',c_val.index[i] , c_val[i-1] , c_val[i]
            buy = c_val[i-1] - c_std
            if c_val[i+1] > buy :
                print 'OK' , c_val[i] , buy
            else:
                print 'error',c_val[i]
# Out:
# --- 2017-10-30 7.65 7.28
# OK 7.28 7.30386532892

# %%
# Out:
# u'2017-10-10'
