# %%
import numpy as np
import pandas as pd 
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fileName='/Users/quchaodong/stu/tmp/20191230.xls'
data = pd.read_excel(fileName )
data.head()
# Out:
#        成交日期      成交时间    证券代码  证券名称  买卖标志    成交价格   成交数量      成交金额  \
# 0  20191101  11:00:05  688018  乐鑫科技  证券买入  133.49    500   66745.0
# 1  20191101  13:47:19  688018  乐鑫科技  证券买入  134.05    600   80430.0
# 2  20191101  14:05:06  688018  乐鑫科技  证券买入  133.77    600   80262.0
# 3  20191101  14:17:57  688018  乐鑫科技  证券买入  133.67    800  106936.0
# 4  20191101  14:22:10    2079  苏州固锝  证券买入    7.40  20000  148000.0
#
#            成交编号    委托价格   委托数量   委托编号        股东代码
# 0  5.590000e+06  133.49    500  56531  E022234594
# 1  8.862697e+06  134.05    600  81762  E022234594
# 2  9.634956e+06  133.77    600  86063  E022234594
# 3  1.019486e+07  133.67    800  91251  E022234594
# 4  1.020000e+14    7.40  20000  92168  0602235843

# %%
dt = data.rename(columns={
        "成交日期": "date1",        
    "成交时间": "time1",
    "证券代码": "code",
                        "证券名称":"name",
                        "买卖标志":"flag",
                         "成交价格":"price",
                        "成交数量":"vol",
                        "成交金额":"money"})

# %%
g= dt.groupby('code')

# %%
#g.head()
x = dt[dt.code==688018]
# Out:
#         date1     time1    code  name  flag    price   vol      money  \
# 0    20191101  11:00:05  688018  乐鑫科技  证券买入  133.490   500   66745.00
# 1    20191101  13:47:19  688018  乐鑫科技  证券买入  134.050   600   80430.00
# 2    20191101  14:05:06  688018  乐鑫科技  证券买入  133.770   600   80262.00
# 3    20191101  14:17:57  688018  乐鑫科技  证券买入  133.670   800  106936.00
# 5    20191101  14:32:42  688018  乐鑫科技  证券买入  133.350   500   66675.00
# 6    20191104  09:30:02  688018  乐鑫科技  证券卖出  134.980   500   67490.00
# 7    20191104  09:33:42  688018  乐鑫科技  证券卖出  136.084   500   68042.00
# 8    20191104  13:42:06  688018  乐鑫科技  证券卖出  135.470   700   94829.00
# 10   20191104  10:23:44  688018  乐鑫科技  证券卖出  134.965   500   67482.46
# 15   20191104  13:53:59  688018  乐鑫科技  证券卖出  138.900   500   69450.00
# 24   20191105  09:46:37  688018  乐鑫科技  证券卖出  136.990   300   41097.00
# 233  20191210  10:44:01  688018  乐鑫科技  证券买入  169.250  2000  338500.00
# 242  20191211  09:39:20  688018  乐鑫科技  证券卖出  172.323  2000  344645.42
#
#            成交编号    委托价格  委托数量   委托编号        股东代码
# 0     5590000.0  133.49   500  56531  E022234594
# 1     8862697.0  134.05   600  81762  E022234594
# 2     9634956.0  133.77   600  86063  E022234594
# 3    10194861.0  133.67   800  91251  E022234594
# 5    10829236.0  133.35   500  95865  E022234594
# 6      124657.0  134.98   500   4621  E022234594
# 7      723396.0  136.02   500  12974  E022234594
# 8     8847410.0  135.47   700  43406  E022234594
# 10    4323198.0  134.90   500  49248  E022234594
# 15    9416484.0  138.90   500  89570  E022234594
# 24    1803341.0  136.99   300  33718  E022234594
# 233   5352665.0  169.25  2000  62686  E022234594
# 242   1278963.0  171.80  2000  24465  E022234594

# %%
def getCodeData(name , oneCodeData):
    a1 = oneCodeData.sort_values(['date1'])
    return a1

# %%
allCodeDetail={}

for name, group in g:
    x = getCodeData (name , group)
    allCodeDetail[name] = x
    
allCodeDetail[21]

# %%
allCodeDetail
# Out:
# {21: None,
#  400: None,
#  425: None,
#  591: None,
#  836: None,
#  938: None,
#  988: None,
#  996: None,
#  998: None,
#  2022: None,
#  2049: None,
#  2079: None,
#  2130: None,
#  2156: None,
#  2185: None,
#  2222: None,
#  2237: None,
#  2298: None,
#  2369: None,
#  2393: None,
#  2897: None,
#  2916: None,
#  2939: None,
#  300129: None,
#  300377: None,
#  600030: None,
#  600100: None,
#  600111: None,
#  600360: None,
#  600369: None,
#  600391: None,
#  600460: None,
#  600489: None,
#  600547: None,
#  600584: None,
#  600703: None,
#  600756: None,
#  600797: None,
#  600879: None,
#  600887: None,
#  600990: None,
#  601398: None,
#  601916: None,
#  601992: None,
#  603019: None,
#  603078: None,
#  603093: None,
#  688008: None,
#  688010: None,
#  688012: None,
#  688018: None,
#  688021: None,
#  688022: None,
#  688088: None,
#  780916: None}
