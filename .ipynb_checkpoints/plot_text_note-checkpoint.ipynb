# %%
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tushare as ts

# %%
ss = ts.get_k_data('002268', ktype='d', autype='qfq', start='2018-04-01')

# %%
y = ss.set_index('date')
plt.figure(figsize=(9, 6))
plt.text(1, 28, r'$\mu=100,\ \sigma=15$')

plt.axis(['2018-4-1', '2018-8-1', 0, 5])
plt.plot(y['close'] ,'b')
#plt.plot(y['close'],'ro')
plt.grid(True)
