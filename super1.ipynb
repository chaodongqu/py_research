# %%
#连续3个季度业绩增长
import numpy as np
import pandas as pd 
# %pylab inline
import matplotlib.pyplot as plt
import tushare as  ts
from sqlalchemy import create_engine

#print(tushare.__version__)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#code,代码
#name,名称
#esp,每股收益
#eps_yoy,每股收益同比(%)
#bvps,每股净资产
#roe,净资产收益率(%)
#epcf,每股现金流量(元)
#net_profits,净利润(万元)
#profits_yoy,净利润同比(%)
#distrib,分配方案
#report_date,发布日期

ts.get_report_data(2018, 2)
# Out:
# [Getting data:]####
#        code   name   eps  eps_yoy  bvps    roe  epcf  net_profits  \
# 0    002353   杰瑞股份  0.19   533.33   NaN   2.31   NaN     18525.94
# 1    000628   高新发展  0.04   -20.00   NaN   1.79   NaN      1365.79
# 2    600343   航天动力  0.02   -14.09   NaN   0.52   NaN      1129.28
# 3    000042   中洲控股  1.08   374.56   NaN  10.60   NaN     71806.05
# 4    300633   开立医疗  0.29    49.47   NaN  10.59   NaN     11795.21
# 5    002316   亚联发展  0.09  -189.60   NaN   4.26   NaN      3625.37
# 6    300371   汇中股份  0.18    91.48   NaN   3.58   NaN      2074.62
# 7    600733  SST前锋 -0.04   337.50   NaN  -3.70   NaN      -699.64
# 8    002437   誉衡药业  0.10     3.11   NaN   5.27   NaN     22593.60
# 9    002017   东信和平  0.06    -9.33   NaN   2.23   NaN      2120.81
# 10   002750   龙津药业  0.03   -53.25   NaN   1.68   NaN      1092.25
# 11   300016   北陆药业  0.26    17.81   NaN   7.67   NaN      8469.12
# 12   002258   利尔化学  0.50    78.57   NaN  10.38   NaN     26064.74
# ...

# %%
#盈利能力¶
#按年度、季度获取盈利能力数据，结果返回的数据属性说明如下：

#code,代码
#name,名称
#roe,净资产收益率(%)
#net_profit_ratio,净利率(%)
#gross_profit_rate,毛利率(%)
#net_profits,净利润(万元)
#esp,每股收益
#business_income,营业收入(百万元)
#bips,每股主营业务收入(元)
#调用方法：

#获取2014年第3季度的盈利能力数据
#ts.get_profit_data(2014,3)

# %%
#成长能力
#按年度、季度获取成长能力数据，结果返回的数据属性说明如下：

#code,代码
#name,名称
#mbrg,主营业务收入增长率(%)
#nprg,净利润增长率(%)
#nav,净资产增长率
#targ,总资产增长率
#epsg,每股收益增长率
#seg,股东权益增长率
#获取2018年第2季度的成长能力数据
ts.get_growth_data(2018,2)
# Out:
# [Getting data:]####
#        code   name      mbrg        nprg       nav      targ        epsg  \
# 0    600569   安阳钢铁   36.8022   3808.5876   39.9018    4.2917   3441.6667
# 1    000537   广宇发展  589.8318   3528.4675  236.5053  257.2666   1700.0000
# 2    600246   万通地产  137.0754    655.1946   12.9482    0.5224    525.7028
# 3    300123   亚光科技  112.7403    516.0098  297.1435  225.6726    190.6250
# 4    002353   杰瑞股份   32.4844    490.1050    2.0125    5.3479    533.3333
# 5    600686   金龙汽车   57.2334    468.7721   26.5187   22.5849     66.6667
# 6    002240   威华股份   31.2952    450.2428   40.4873   27.4821    575.4717
# 7    002761    多喜爱   32.1731    413.1775    8.3685    7.8415    100.0000
# 8    000042   中洲控股   82.4322    370.0453   25.1400   25.0905    374.5606
# 9    000818   航锦科技   22.3091    316.9261   17.2374   48.8726    296.3760
# 10   603903   中持股份  191.3455    310.7523   18.6271  110.4205    259.2046
# 11   002490   山东墨龙   63.5619    286.3167    3.2715    9.5514    363.6364
# ...

# %%
s2 = ts.get_growth_data(2018,2)
# Out:
# [Getting data:]####

# %%
s2
# Out:
#        code   name      mbrg        nprg       nav      targ        epsg  \
# 0    600569   安阳钢铁   36.8022   3808.5876   39.9018    4.2917   3441.6667
# 1    000537   广宇发展  589.8318   3528.4675  236.5053  257.2666   1700.0000
# 2    600246   万通地产  137.0754    655.1946   12.9482    0.5224    525.7028
# 3    300123   亚光科技  112.7403    516.0098  297.1435  225.6726    190.6250
# 4    002353   杰瑞股份   32.4844    490.1050    2.0125    5.3479    533.3333
# 5    600686   金龙汽车   57.2334    468.7721   26.5187   22.5849     66.6667
# 6    002240   威华股份   31.2952    450.2428   40.4873   27.4821    575.4717
# 7    002761    多喜爱   32.1731    413.1775    8.3685    7.8415    100.0000
# 8    000042   中洲控股   82.4322    370.0453   25.1400   25.0905    374.5606
# 9    000818   航锦科技   22.3091    316.9261   17.2374   48.8726    296.3760
# 10   603903   中持股份  191.3455    310.7523   18.6271  110.4205    259.2046
# 11   002490   山东墨龙   63.5619    286.3167    3.2715    9.5514    363.6364
# ...

# %%
#df[df['creativeID']<=10000]
s2 = ts.get_growth_data(2018,2)
# Out:
# [Getting data:]####

# %%
connect = create_engine("mysql://root:qucd123456@127.0.0.1:3306/test",
                        encoding="utf-8",
                        echo=True)  # 连接数据库，echo=True =>把所有的信息都打印出来

# %%
s2.to_sql('growth_data',connect,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...

# %%
#df[df['creativeID']<=10000]
#s2[s2['mbrg'>100]]
